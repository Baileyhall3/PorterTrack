# %% [markdown]
# <a href="https://colab.research.google.com/github/Baileyhall3/PorterTrack/blob/master/NavPrototypeColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from folium import plugins
import pandas as pd

import ipywidgets
import os
import json

from IPython.display import display
import IPython
#from IPython import display
import datetime

#!git clone https://github.com/Baileyhall3/PorterTrack.git

hospitalLocation = (54.973523, -1.625129)
hospitalMap = folium.Map(location = hospitalLocation, width = "75%", zoom_start = 17)

for files in os.listdir('PorterTrack/Geo/GeoResources'):
  print(files)
  #folium.GeoJson(files).add_to(map_UMM)

CAS = 'PorterTrack/Geo/GeoResources/CAS.geojson'
folium.GeoJson(CAS, name="CAS").add_to(hospitalMap)

MXR = 'PorterTrack/Geo/GeoResources/MXR.geojson'
folium.GeoJson(MXR, name="MXR").add_to(hospitalMap)

Theatres = 'PorterTrack/Geo/GeoResources/Theatres.geojson'
folium.GeoJson(Theatres, name="Theatres").add_to(hospitalMap)

Ward3 = 'PorterTrack/Geo/GeoResources/Ward3.geojson'
folium.GeoJson(Ward3, name="Ward3").add_to(hospitalMap)

Pathology = 'PorterTrack/Geo/GeoResources/Pathology.geojson'
folium.GeoJson(Pathology, name="Pathology").add_to(hospitalMap)

EAU = 'PorterTrack/Geo/GeoResources/EAU.geojson'
folium.GeoJson(EAU, name="EAU").add_to(hospitalMap)

TC = 'PorterTrack/Geo/GeoResources/TC.geojson'
folium.GeoJson(TC, name="TC").add_to(hospitalMap)

Ward2 = 'PorterTrack/Geo/GeoResources/Ward2.geojson'
folium.GeoJson(Ward2, name="Ward2").add_to(hospitalMap)

CT = 'PorterTrack/Geo/GeoResources/CT.geojson'
folium.GeoJson(CT, name="CT").add_to(hospitalMap)

ECG = 'PorterTrack/Geo/GeoResources/ECG.geojson'
folium.GeoJson(ECG, name="ECG").add_to(hospitalMap)

Ultrasound = 'PorterTrack/Geo/GeoResources/Ultrasound.geojson'
folium.GeoJson(Ultrasound, name="Ultrasound").add_to(hospitalMap)

ECG = 'PorterTrack/Geo/GeoResources/ECG.geojson'
folium.GeoJson(ECG, name="ECG").add_to(hospitalMap)

Kitchen = 'PorterTrack/Geo/GeoResources/Kitchen.geojson'
folium.GeoJson(Kitchen, name="Kitchen").add_to(hospitalMap)

Ward4 = 'PorterTrack/Geo/GeoResources/Ward4.geojson'
folium.GeoJson(Ward4, name="Ward4").add_to(hospitalMap)

Ward1 = 'PorterTrack/Geo/GeoResources/Ward1.geojson'
folium.GeoJson(Ward1, name="Ward1").add_to(hospitalMap)

hospitalMap
# Out:
# CAS.geojson
# MXR.geojson
# Theatres.geojson
# Ward3.geojson
# Pathology.geojson
# EAU.geojson
# TC.geojson
# Ward2.geojson
# CT.geojson
# ECG.geojson
# Ultrasound.geojson
# Kitchen.geojson
# Ward4.geojson
# Ward1.geojson
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
